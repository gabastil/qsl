# %%
import qsl
print(qsl.__version__)

CONFIG = {
    "advanceOnSave": True,
    "allowConfigChange": True,
    "batchSize": 1,
    "items": [
        {"target": "./qsl/testing/data/image1.jpg"},
        {"target": "./qsl/testing/data/image3.jpg"}
    ],
    "maxCanvasSize": 512,
    "maxViewHeight": 512,
    "mode": "light",
    "config": {
        "image": [
            {
                "name": "Apparent Maturity",
                "multiple": False,
                "options": [
                    {
                        "name": "Infant/toddler",
                        "shortcut": "1"
                    },
                    {
                        "name": "Prepubescent",
                        "shortcut": "2"
                    },
                    {
                        "name": "Peripubescent",
                        "shortcut": "3"
                    },
                    {
                        "name": "Pubescent",
                        "shortcut": "4"
                    },
                    {
                        "name": "Postpubescent minor/adult indeterminate",
                        "shortcut": "5"
                    },
                    {
                        "name": "Adult",
                        "shortcut": "6"
                    },
                    {
                        "name": "None",
                        "shortcut": "`"
                    },
                    {
                        "name": "Unsure",
                        "shortcut": "t"
                    }
                ]
            },
            {
                "name": "Nudity",
                "multiple": False,
                "options": [
                    {
                        "name": "Genitalia seen",
                        "shortcut": "f"
                    },
                    {
                        "name": "Nudity without genitalia",
                        "shortcut": "d"
                    },
                    {
                        "name": "Partially unclothed",
                        "shortcut": "s"
                    },
                    {
                        "name": "No nudity",
                        "shortcut": "a"
                    },
                    {
                        "name": "Unsure",
                        "shortcut": "v"
                    }
                ]
            },
            {
                "name": "Sexual Acts",
                "multiple": False,
                "options": [
                    {
                        "name": "Penetrative sex activity",
                        "shortcut": "h"
                    },
                    {
                        "name": "Non-penetrative sex activity",
                        "shortcut": "j"
                    },
                    {
                        "name": "Overtly sexualized posing",
                        "shortcut": "k"
                    },
                    {
                        "name": "Sexualized situation",
                        "shortcut": "l"
                    },
                    {
                        "name": "Exploitative",
                        "shortcut": ";"
                    },
                    {
                        "name": "Not sexual",
                        "shortcut": "'"
                    },
                    {
                        "name": "Unsure",
                        "shortcut": "b"
                    }
                ]
            },
            {
                "name": "Other",
                "multiple": False,
                "options": [
                    {
                        "name": "Investigative interest",
                        "shortcut": "i"
                    }
                ]
            }
        ]
    }
}

qsl.MediaLabeler(**CONFIG)
# Out:
# 0.2.41
# MediaLabeler(buttons={'prev': False, 'next': True, 'save': True, 'config': True, 'delete': False, 'ignore': Tr…
